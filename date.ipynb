# %%
# %reset -f
import os
import cv2
import numpy as np
from IPython.display import Image

# 入力画像のパス設定 (Path設定)
input_path = 'data/download/' + 'char-chip-01.png'

# 出力画像のパス設定 (Path設定)
output_fn = 'reimu.png'
output_dir = 'data/img/'
output_path = output_dir + output_fn

# 出力フォルダが存在しなければ作成
if not os.path.isdir(output_dir):
  os.makedirs(output_dir)

# 画像読込み、切り出し範囲の設定
img = cv2.imread(input_path,cv2.IMREAD_UNCHANGED) # アルファチャンネルも読み込む
print(f'raw.shape => {img.shape}')
bw = 24  # BaseWidth 
bh = 32  # BaseHeight
offset_w = bw*0
offset_h = bh*0

# 画像の切り出しと保存処理
img = img[offset_h:offset_h+bh*4, offset_w:offset_w+bw*3]
cv2.imwrite(output_path,img)
print(f'{output_path} に画像を出力しました。')

# 出力画像の確認
Image(open(output_path,'rb').read())
# Out:
# raw.shape => (256, 288, 4)
# data/img/reimu.png に画像を出力しました。

# %%
# 画像の詳細確認
# %reset -f
import cv2
import numpy as np
import matplotlib.pyplot as plt

# 入力画像のパス設定 (Path設定)
input_dir = 'data/download/'
input_fn = 'map-ground-center.png'
input_path = input_dir + input_fn

# 出力画像のパス設定 (Path設定)
output_dir = 'data/img/'
output_fn = 'map-ground-center.png'
output_path = output_dir + output_fn

# アルファチャンネルを含めて画像読込み
raw = cv2.imread(input_path, cv2.IMREAD_UNCHANGED)

# 画像の範囲切り出しと拡大
img = raw[0:500,0:500] # ■■ 要修正
img = cv2.resize(img,(48,48),interpolation=cv2.INTER_NEAREST)
height, width, _ = img.shape

# 可視化に関する処理
fig,ax = plt.subplots(dpi=140)
ax.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB),interpolation='nearest')
ax.set_xlim(-0.5,width-0.5)
ax.set_ylim(height-0.5,-0.5)

# 主目盛の設定
plt.tick_params(length=0, labeltop=True, labelright=True )
ax.set_xticks(np.arange(0, width))
ax.set_xticklabels(np.arange(0, width),fontsize=5)
ax.set_yticks(np.arange(0, height))
ax.set_yticklabels(np.arange(0, height),fontsize=5)

# 副主目盛の設定
plt.tick_params(which='minor', 
                length=0, labeltop=True, labelright=True )
ax.set_xticks(np.arange(0.5, width-0.5,1), minor=True)
ax.set_yticks(np.arange(0.5, height-0.5,1), minor=True)

# グリッド設定と表示
ax.grid(which='minor', color='#999')
plt.show()

# 保存
cv2.imwrite(output_path,img)
# Out:
# True

# %%
# 画像の詳細確認
# %reset -f
import cv2
import numpy as np
import matplotlib.pyplot as plt

# 入力画像のパス設定 (Path設定)
input_dir = 'data/download/'
input_fn = 'hara.png'
input_path = input_dir + input_fn

# 出力画像のパス設定 (Path設定)
output_dir = 'data/img/'
output_fn = 'hara.png'
output_path = output_dir + output_fn

# アルファチャンネルを含めて画像読込み
raw = cv2.imread(input_path, cv2.IMREAD_UNCHANGED)

# 画像の範囲切り出しと拡大
img = raw[0:500,0:500] # ■■ 要修正
img = cv2.resize(img,(48,48),interpolation=cv2.INTER_NEAREST)
height, width, _ = img.shape

# 可視化に関する処理
fig,ax = plt.subplots(dpi=140)
ax.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB),interpolation='nearest')
ax.set_xlim(-0.5,width-0.5)
ax.set_ylim(height-0.5,-0.5)

# 主目盛の設定
plt.tick_params(length=0, labeltop=True, labelright=True )
ax.set_xticks(np.arange(0, width))
ax.set_xticklabels(np.arange(0, width),fontsize=5)
ax.set_yticks(np.arange(0, height))
ax.set_yticklabels(np.arange(0, height),fontsize=5)

# 副主目盛の設定
plt.tick_params(which='minor', 
                length=0, labeltop=True, labelright=True )
ax.set_xticks(np.arange(0.5, width-0.5,1), minor=True)
ax.set_yticks(np.arange(0.5, height-0.5,1), minor=True)

# グリッド設定と表示
ax.grid(which='minor', color='#999')
plt.show()

# 保存
cv2.imwrite(output_path,img)
# Out:
# True

# %%
# 画像の詳細確認
# %reset -f
import cv2
import numpy as np
import matplotlib.pyplot as plt

# 入力画像のパス設定 (Path設定)
input_dir = 'data/money/'
input_fn = 'crown.png'
input_path = input_dir + input_fn

# 出力画像のパス設定 (Path設定)
output_dir = 'data/img/'
output_fn = 'crown.png'
output_path = output_dir + output_fn

# アルファチャンネルを含めて画像読込み
raw = cv2.imread(input_path, cv2.IMREAD_UNCHANGED)

# 画像の範囲切り出しと拡大
img = raw[0:500,0:500] # ■■ 要修正
img = cv2.resize(img,(48,48),interpolation=cv2.INTER_NEAREST)
height, width, _ = img.shape

# 可視化に関する処理
fig,ax = plt.subplots(dpi=140)
ax.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB),interpolation='nearest')
ax.set_xlim(-0.5,width-0.5)
ax.set_ylim(height-0.5,-0.5)

# 主目盛の設定
plt.tick_params(length=0, labeltop=True, labelright=True )
ax.set_xticks(np.arange(0, width))
ax.set_xticklabels(np.arange(0, width),fontsize=5)
ax.set_yticks(np.arange(0, height))
ax.set_yticklabels(np.arange(0, height),fontsize=5)

# 副主目盛の設定
plt.tick_params(which='minor', 
                length=0, labeltop=True, labelright=True )
ax.set_xticks(np.arange(0.5, width-0.5,1), minor=True)
ax.set_yticks(np.arange(0.5, height-0.5,1), minor=True)

# グリッド設定と表示
ax.grid(which='minor', color='#999')
plt.show()

# 保存
cv2.imwrite(output_path,img)
# Out:
# True

# %%
# 画像の詳細確認
# %reset -f
import cv2
import numpy as np
import matplotlib.pyplot as plt

# 入力画像のパス設定 (Path設定)
input_dir = 'data/お金/'
input_fn = '1円.png'
input_path = input_dir + input_fn

# 出力画像のパス設定 (Path設定)
output_dir = 'data/img/'
output_fn = '1enn.png'
output_path = output_dir + output_fn

# アルファチャンネルを含めて画像読込み
raw = cv2.imread(input_path, cv2.IMREAD_UNCHANGED)

# 画像の範囲切り出しと拡大
img = raw[0:500,0:500] # ■■ 要修正
img = cv2.resize(img,(48,48),interpolation=cv2.INTER_NEAREST)
height, width, _ = img.shape

# 可視化に関する処理
fig,ax = plt.subplots(dpi=140)
ax.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB),interpolation='nearest')
ax.set_xlim(-0.5,width-0.5)
ax.set_ylim(height-0.5,-0.5)

# 主目盛の設定
plt.tick_params(length=0, labeltop=True, labelright=True )
ax.set_xticks(np.arange(0, width))
ax.set_xticklabels(np.arange(0, width),fontsize=5)
ax.set_yticks(np.arange(0, height))
ax.set_yticklabels(np.arange(0, height),fontsize=5)

# 副主目盛の設定
plt.tick_params(which='minor', 
                length=0, labeltop=True, labelright=True )
ax.set_xticks(np.arange(0.5, width-0.5,1), minor=True)
ax.set_yticks(np.arange(0.5, height-0.5,1), minor=True)

# グリッド設定と表示
ax.grid(which='minor', color='#999')
plt.show()

# 保存
cv2.imwrite(output_path,img)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 21
#      18 raw = cv2.imread(input_path, cv2.IMREAD_UNCHANGED)
#      20 # 画像の範囲切り出しと拡大
# ---> 21 img = raw[0:500,0:500] # ■■ 要修正
#      22 img = cv2.resize(img,(48,48),interpolation=cv2.INTER_NEAREST)
#      23 height, width, _ = img.shape
#
# TypeError: 'NoneType' object is not subscriptable
